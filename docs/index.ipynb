# %% [markdown]
# # Parameteriser tutorial

# %%
from parameteriser.brenda.v0 import Brenda

# %%
brenda = Brenda()
kms, kcats = brenda.get_kms_and_kcats(
    ec="4.1.1.39",
    add_uniprot_sequences=True,
    filter_mutant=True,
    filter_missing_sequences=True,
)
kms.head()
